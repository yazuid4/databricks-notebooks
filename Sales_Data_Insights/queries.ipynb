# %%
# %fs ls adl://cadlstore2hxco2cjxvxkw.azuredatalakestore.net/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>adl://cadlstore2hxco2cjxvxkw.azuredatalakestore.net/countries.json</td><td>countries.json</td><td>114118</td><td>1708866360843</td></tr><tr><td>adl://cadlstore2hxco2cjxvxkw.azuredatalakestore.net/customers.json</td><td>customers.json</td><td>69292</td><td>1708866362702</td></tr><tr><td>adl://cadlstore2hxco2cjxvxkw.azuredatalakestore.net/orders.json</td><td>orders.json</td><td>671174</td><td>1708866374748</td></tr><tr><td>adl://cadlstore2hxco2cjxvxkw.azuredatalakestore.net/products.json</td><td>products.json</td><td>994</td><td>1708866361061</td></tr><tr><td>adl://cadlstore2hxco2cjxvxkw.azuredatalakestore.net/sales.json</td><td>sales.json</td><td>4154197</td><td>1708866423416</td></tr></tbody></table></div>

# %%
# %python
configs = {
  "fs.adl.oauth2.access.token.provider.type": "CustomAccessTokenProvider",
  "fs.adl.oauth2.access.token.custom.provider": spark.conf.get("spark.databricks.passthrough.adls.tokenProviderClassName")
}
dbutils.fs.mount(
source = "adl://cadlstore2hxco2cjxvxkw.azuredatalakestore.net/",
mount_point = "/mnt/datalake",
extra_configs = configs)
# Out:
# True

# %%
# %sql
CREATE TABLE countries
USING json
OPTIONS (
path "/mnt/datalake/countries.json"
);
CREATE TABLE customers
USING json
OPTIONS (
  path "/mnt/datalake/customers.json"
);
CREATE TABLE orders
USING json
OPTIONS (
  path "/mnt/datalake/orders.json"
);
CREATE TABLE products
USING json
OPTIONS (
  path "/mnt/datalake/products.json"
);
CREATE TABLE sales
USING json
OPTIONS (
  path "/mnt/datalake/sales.json"
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Number of countries that use the currency code 'EUR' to conduct business according to countries data?

# %%
# %sql
SELECT count(currency) FROM countries
WHERE currency = 'EUR';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(currency)</th></tr></thead><tbody><tr><td>28</td></tr></tbody></table></div>

# %% [markdown]
# Number of customers they deal with in the country of Indonesia ?

# %%
# %sql
SELECT count(DISTINCT customerId) FROM (
  SELECT * FROM customers c 
  JOIN countries ct 
  ON c.country = ct.country
  WHERE ct.name = "Indonesia"
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT customerId)</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %% [markdown]
# Currency code that had the maximum number sales transaction records for sales orders created in 2019?

# %%
# %sql
SELECT ct.currency, count(s.saleId) AS nb_sales FROM sales s
  JOIN orders o
  ON s.orderId = o.orderId
  JOIN customers c 
  ON c.customerId = o.customerId
  JOIN countries ct 
  ON c.country = ct.country
WHERE EXTRACT(YEAR FROM CAST(o.date AS DATE)) = 2019
GROUP BY ct.Currency
ORDER BY nb_sales DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>currency</th><th>nb_sales</th></tr></thead><tbody><tr><td>EUR</td><td>3399</td></tr><tr><td>XCD</td><td>1609</td></tr><tr><td>USD</td><td>1295</td></tr><tr><td>XOF</td><td>1256</td></tr><tr><td>XAF</td><td>1133</td></tr><tr><td>GBP</td><td>663</td></tr><tr><td>AUD</td><td>470</td></tr><tr><td>CNY</td><td>459</td></tr><tr><td>PGK</td><td>457</td></tr><tr><td>SHP</td><td>440</td></tr><tr><td>PKR</td><td>375</td></tr><tr><td>TND</td><td>343</td></tr><tr><td>PAB</td><td>325</td></tr><tr><td>MAD</td><td>321</td></tr><tr><td>XPF</td><td>320</td></tr><tr><td>BGN</td
>84</td></tr><tr><td>INR</td><td>83</td></tr><tr><td>MNT</td><td>82</td></tr><tr><td>CVE</td><td>75</td></tr><tr><td>KZT</td><td>74</td></tr><tr><td>VUV</td><td>70</td></tr><tr><td>MDL</td><td>69</td></tr><tr><td>BRL</td><td>69</td></tr><tr><td>KPW</td><td>68</td></tr><tr><td>ILS</td><td>68</td></tr><tr><td>TJS</td><td>68</td></tr><tr><td>NIO</td><td>66</td></tr><tr><td>HRK</td><td>63</td></tr><tr><td>SYP</td><td>63</td></tr><tr><td>GYD</td><td>62</td></tr><tr><td>RUB</td><td>61</td></tr><tr><td>DOP</td><td>61</td></tr><tr><td>SZL</td><td>60</td></tr><tr><td>CRC</td><td>58</td></tr><tr><td>BBD</td><td>53< ...

# %% [markdown]
# Customers which have one of the letters q, x, or z in there name.

# %%
# %sql
SELECT count(customerId) FROM customers
WHERE active = 'true'
AND LOWER(name) REGEXP '[qxz]'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(customerId)</th></tr></thead><tbody><tr><td>39</td></tr></tbody></table></div>

# %% [markdown]
# Top customer in terms of confirmed order quantities (the sum of sales quantities in the order) for products manufactured in the OCEANIA region.

# %%
# %sql
select c.customerId, c.name, ct.name, qy.orderId, qy.total_quantity from customers c 
join countries ct on c.country = ct.country
join     
(select o.orderId, o.customerId, sum(s.quantity) as total_quantity
from sales s
  join orders o on s.orderId = o.orderId
  join products p on p.productId = s.productId
  join countries ct on ct.Country = p.ManufacturedCountry
where ct.region = 'OCEANIA'
group by o.orderId, o.customerId ) qy on qy.customerId = c.customerId
order by qy.total_quantity desc;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customerId</th><th>name</th><th>name</th><th>orderId</th><th>total_quantity</th></tr></thead><tbody><tr><td>243</td><td>Quentin Harvey</td><td>Congo, Repub. of the</td><td>6905</td><td>29</td></tr><tr><td>300</td><td>Joseph Trujillo</td><td>Cameroon</td><td>3587</td><td>24</td></tr><tr><td>351</td><td>Burton Key</td><td>Papua New Guinea</td><td>2131</td><td>22</td></tr><tr><td>370</td><td>Keane Rich</td><td>Kyrgyzstan</td><td>6550</td><td>21</td></tr><tr><td>116</td><td>Chandler Perkins</td><td>Georgia</td><td>11203</td><td>20</td></tr><tr><td>287</td><td>Kaseem Gibbs</td><td>Guatemala</td><td>1223</td><td>20</td></tr><tr><td>117</td><td>August Ramirez</td><td>Saint Vincent and the Grenadines</td><td>11096</td><td>20</td></tr><tr><td>368</td><td>Fuller Ball</td><td>Netherlands</td><td>1592</td><td>19</td></tr><tr><td>386</td><td>Ferdinand Campbell</td><td>Kazakhstan</td><td>9677</td><td>19</td></tr><tr><td>45</td><td>Peter Hubbard</td><td>Bolivia</td><td>8189</td><td>19</td></tr><tr><td>270</td><td>Rigel Conrad</td><td>Aruba</td><td>6249</td><td>19</td></tr><tr><td>252</td><td>Valentine Morrow</td><td>Ukraine</td><td>6026</td><td>18</td></tr><tr><td>20</td><td>Keith Pittman</td><td>Afghanistan</td><td>3221</td><td>18</td></tr><tr><td>14</td><td>Jasper Miller</td><td>Guinea</td><td>7556</td><td>18</td></tr><tr><td>124</td><td>Hilel Sparks</td><td>Western Sahara</td><td>1057</td><td>18</td></tr><tr><td>44</td><td>Vladimir Parks</td><td>Mali</td><td>753</td><td>18</td></tr><tr><td>222</td><td>Amos Herrera</td><td>Taiw
r><tr><td>Mohammad Kane</td><td>651</td></tr><tr><td>Warren Mcgee</td><td>651</td></tr><tr><td>Tyler Odonnell</td><td>651</td></tr><tr><td>Caesar Gibson</td><td>650</td></tr><tr><td>Emmanuel Sosa</td><td>649</td></tr><tr><td>August Ramirez</td><td>649</td></tr><tr><td>Burton Key</td><td>648</td></tr><tr><td>Chancellor Bradford</td><td>647</td></tr><tr><td>Hu Pitts</td><td>647</td></tr><tr><td>Cooper Rowland</td><td>645</td></tr><tr><td>Ezra Savage</td><td>644</td></tr><tr><td>Herrod Moore</td><td>644</td></tr><tr><td>Branden Mullen</td><td>644</td></tr><tr><td>Reece Molina</td><td>642</td></tr><tr><td>Kamal Blevins</td><td>642</td></tr><tr><td>Devin Chen</td><td>642</td></tr><tr><t ...

# %% [markdown]
# Aggregated weight in grams of the sales where the sales transactions happened in the Currency CAD.

# %%
# %sql
select sum(p.WeightGrams) from sales s 
  join products p 
  on s.ProductId = p.ProductId
  join orders o 
  on o.OrderId = s.OrderId
  join customers c 
  on c.CustomerId = o.CustomerId
  join countries ct 
  on c.Country = ct.Country
where ct.Currency = 'CAD'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(WeightGrams)</th></tr></thead><tbody><tr><td>49096</td></tr></tbody></table></div>

# %% [markdown]
# How many customer orders were placed in 2018, for customers in regions EASTERN EUROPE and WESTERN EUROPE?

# %%
# %sql
select count(*) from orders o
  join customers c 
  on o.CustomerId = c.CustomerId
  join countries ct 
  on c.Country = ct.Country
where (ct.Region = 'EASTERN EUROPE' or ct.Region = 'WESTERN EUROPE')
and extract(year from cast(o.date as DATE)) = '2018'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>1014</td></tr></tbody></table></div>

# %% [markdown]
# The total cumulative sales quantity for the customers in the countries Thailand, Indonesia, and Vietnam?

# %%
# %sql
select sum(s.Quantity) from sales s 
  join orders o 
  on o.OrderId = s.OrderId
  join customers c 
  on c.CustomerId = o.CustomerId
  join countries ct 
  on c.Country = ct.Country
where ct.name in ('Thailand', 'Indonesia', 'Vietnam')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(Quantity)</th></tr></thead><tbody><tr><td>1195</td></tr></tbody></table></div>

# %% [markdown]
# Which order had the maximum cumulative product quantities (sum of product quantities in each sale included in the order) on '2018-06-05'?

# %%
# %sql
select o.OrderId, sum(s.Quantity) as total_quantity from orders o 
  join sales s 
  on o.OrderId = s.OrderId
where o.Date = '2018-06-05'
group by o.OrderId
order by total_quantity desc;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>OrderId</th><th>total_quantity</th></tr></thead><tbody><tr><td>2253</td><td>46</td></tr><tr><td>2248</td><td>43</td></tr><tr><td>2242</td><td>41</td></tr><tr><td>2240</td><td>33</td></tr><tr><td>2232</td><td>32</td></tr><tr><td>2249</td><td>29</td></tr><tr><td>2236</td><td>28</td></tr><tr><td>2235</td><td>28</td></tr><tr><td>2252</td><td>28</td></tr><tr><td>2247</td><td>26</td></tr><tr><td>2244</td><td>26</td></tr><tr><td>2234</td><td>25</td></tr><tr><td>2243</td><td>18</td></tr><tr><td>2250</td><td>15</td></tr><tr><td>2254</td><td>15</td></tr><tr><td>2251</td><td>10</td></tr><tr><td>2241</td><td>9</td></tr><tr><td>2245</td><td>7</td></tr><tr><td>2237</td><td>3</td></tr><tr><td>2246</td><td>2</td></tr><tr><td>2238</td><td>1</td></tr><tr><td>2233</td><td>1</td></tr></tbody></table></div>
